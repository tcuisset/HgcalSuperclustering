# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import awkward as ak
import matplotlib.pyplot as plt
import mplhep as hep
plt.style.use(hep.style.CMS)
import hist

import sys
sys.path.append("../..")
from analyzer.dumperReader.reader import *
from analyzer.driver.fileTools import *
from analyzer.driver.computations import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dumperInput = DumperInputManager("/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1/")
reader= dumperInput.getReader(0)

# %%
assocs_bestScore(assocs_dropOnes(assocs_zip_recoToSim(reader.associations)))
# Out:
# <Array [[{ts_id: 19, ...}, ..., {...}], ...] type='100 * var * {ts_id: int6...'>

# %%
pd.options.display.min_rows=50

# %%
reader.assocs_bestScore_recoToSim_df()
# Out:
#                      simts_id     score    sharedE
# eventInternal ts_id
# 0             0             0  0.966305   0.000182
#               1             0  0.997339   0.044401
#               2             0  0.969742   0.096398
#               3             0  0.998178   0.000368
#               4             0  0.999078   0.012921
#               5             0  0.964695   0.009293
#               6             0  0.979735   0.080785
#               7             0  0.990220   0.002180
#               8             0  0.997095   0.001848
#               9             0  0.927226   0.026630
#               10            0  0.924755   0.042007
#               11            0  0.999578   0.001229
#               12            0  0.960555   0.004936
#               13            0  0.166949   3.543109
#               14            0  0.900342   0.537169
#               15            0  0.823452   0.181505
#               16            0  0.996988   0.001814
# ...

# %%
df = reader.supercluster_df.join(reader.assocs_bestScore_recoToSim_df(), on=["eventInternal", "ts_id"])
df.score = df.score.fillna(1)
df
# Out:
#                                              ts_id  simts_id     score  \
# eventInternal supercls_id ts_in_supercls_id
# 0             0           0                   2359       NaN  1.000000
#                           1                   2492       NaN  1.000000
#               1           0                    626       NaN  1.000000
#                           1                    537       NaN  1.000000
#                           2                    392       NaN  1.000000
#                           3                     36       0.0  0.927329
#               2           0                   1658       NaN  1.000000
#                           1                    479       NaN  1.000000
#                           2                    188       NaN  1.000000
#               3           0                    766       NaN  1.000000
#                           1                    191       NaN  1.000000
#               4           0                    588       NaN  1.000000
# ...

# %%
supercluster_joinTracksters(df, reader.tracksters)
# Out:
#                                              ts_id  simts_id     score  \
# eventInternal supercls_id ts_in_supercls_id
# 0             0           0                   2359       NaN  1.000000
#                           1                   2492       NaN  1.000000
#               1           0                    626       NaN  1.000000
#                           1                    537       NaN  1.000000
#                           2                    392       NaN  1.000000
#                           3                     36       0.0  0.927329
#               2           0                   1658       NaN  1.000000
#                           1                    479       NaN  1.000000
#                           2                    188       NaN  1.000000
#               3           0                    766       NaN  1.000000
#                           1                    191       NaN  1.000000
#               4           0                    588       NaN  1.000000
# ...
