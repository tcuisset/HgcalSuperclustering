# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import awkward as ak
import pandas as pd
import matplotlib.pyplot as plt
import mplhep as hep
plt.style.use(hep.style.CMS)
import hist

import sys
sys.path.append("/workspaces/cmssw/")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
store = pd.HDFStore("/workspaces/repo/scratch/analyzer-test/store.hdf", mode="r")
df = store["CPToSupercluster"]
df
# Out:
#                               supercls_id  seed_ts_id  raw_energy_supercls  \
# eventInternal genparticle_id
# 0             0                         1         652           267.032257
#               1                         2        2224           558.274780
# 1             0                         1         779           374.847046
#               1                         2        2308           179.098740
# 2             0                        54         500            72.663040
#               1                         0        2134           169.952988
# 3             0                         2         737           183.937622
#               1                         0        2243           330.052643
# 4             0                         2         794           195.886124
#               1                      2261        2525           194.904221
# 5             0                         1         968           369.903778
# ...

# %%
h = hist.Hist(hist.axis.Regular(50, 0, 2, name="e_ratio", label="Supercluster energy / CaloParticle energy"))
h.fill(df.regressed_energy_supercls/df.regressed_energy_CP)

hep.histplot(h)
plt.ylabel("Events")
# Out:
# Text(0, 1, 'Events')
