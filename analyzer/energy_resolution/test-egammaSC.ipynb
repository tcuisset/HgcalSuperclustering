# %%
# %load_ext autoreload
# %autoreload 2
import uproot
import numpy as np
import awkward as ak
import pandas as pd
import matplotlib.pyplot as plt
import mplhep as hep
plt.style.use(hep.style.CMS)
import hist


import sys
sys.path.append("../..")
from functools import partial

from analyzer.dumperReader.reader import *
from analyzer.driver.fileTools import *
from analyzer.driver.computations import *
from analyzer.computations.CPToSupercls import CPToSuperclusterProperties
from analyzer.computations.tracksters import tracksters_seedProperties, CPtoTrackster_properties
from analyzer.energy_resolution.fit import *

# %%
dumperInput = DumperInputManager([
    "/data_cms_upgrade/cuisset/supercls/alessandro_electrons/reco-v7/",
    "/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/v14-dnn",
    #"/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v11/"
    ], 
                                limitFileCount=None,# restrictToAvailableDumperTypes=[DumperType.TICL, DumperType.TICLsupercls]
                                )

# %%
t = uproot.open("/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/v14-dnn/step3_DNN_1.root:Events")

# %%
t.show(name_width=200)
# Out:
# name                                                                                                                                                                                                     | typename                 | interpretation
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------+-------------------------------
# EventAuxiliary                                                                                                                                                                                           | edm::EventAuxiliary      | AsObjects(Model_edm_3a3a_Ev...
# EventProductProvenance                                                                                                                                                                                   | std::vector<edm::Stor... | AsJagged(AsStridedObjects(M...
# EventSelections                                                                                                                                                                                          | std::vector<edm::Hash... | AsObjects(AsVector(True, Mo...
# BranchListIndexes                                                                                                                                                                                        | std::vector<uint16_t>    | AsJagged(AsDtype('>u2'), he...
# TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO.                                                                                                                                        | edm::Wrapper<edm::Ass... | AsGroup(<TBranchElement 'Tr...
# TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO./TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO.obj                                                                   | (group of Trajectorys... | AsGroup(<TBranchElement 'Tr...
# TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO./TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO.obj/TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RE... | unknown                  | <UnknownInterpretation 'non...
# TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO./TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO.obj/TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RE... | unknown                  | <UnknownInterpretation 'non...
# TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO./TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO.obj/TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RE... | (group of Trajectorys... | AsGroup(<TBranchElement 'Tr...
# TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO./TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO.obj/TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RE... | uint16_t[]               | AsJagged(AsDtype('>u2'))
# TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO./TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO.obj/TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RE... | uint16_t[]               | AsJagged(AsDtype('>u2'))
# TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO./TrajectorysToOnerecoGsfTracksAssociation_electronGsfTracks__RECO.present                                                               | bool                     | AsDtype('bool')
# TrackingRecHitsOwned_electronGsfTracks__RECO.                                                                                                                                                            | edm::Wrapper<edm::Own... | AsGroup(<TBranchElement 'Tr...
# TrackingRecHitsOwned_electronGsfTracks__RECO./TrackingRecHitsOwned_electronGsfTracks__RECO.obj                                                                                                           | (group of TrackingRec... | AsGroup(<TBranchElement 'Tr...
# TrackingRecHitsOwned_electronGsfTracks__RECO./TrackingRecHitsOwned_electronGsfTracks__RECO.obj/TrackingRecHitsOwned_electronGsfTracks__RECO.obj.data_                                                    | unknown                  | <UnknownInterpretation 'non...
# TrackingRecHitsOwned_electronGsfTracks__RECO./TrackingRecHitsOwned_electronGsfTracks__RECO.present                                                                                                       | bool                     | AsDtype('bool')
# TICLCandidates_ticlCandidate__RECO.                                                                                                                                                                      | edm::Wrapper<vector<T... | AsGroup(<TBranchElement 'TI...
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj                                                                                                                               | (group of TICLCandida... | AsGroup(<TBranchElement 'TI...
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.m_state.vertex_.fCoordinates.fX                                                        | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.m_state.vertex_.fCoordinates.fY                                                        | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.m_state.vertex_.fCoordinates.fZ                                                        | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.m_state.p4Polar_.fCoordinates.fPt                                                      | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.m_state.p4Polar_.fCoordinates.fEta                                                     | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.m_state.p4Polar_.fCoordinates.fPhi                                                     | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.m_state.p4Polar_.fCoordinates.fM                                                       | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.m_state.qx3_                                                                           | int32_t[]                | AsJagged(AsDtype('>i4'))
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.m_state.pdgId_                                                                         | int32_t[]                | AsJagged(AsDtype('>i4'))
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.m_state.status_                                                                        | int32_t[]                | AsJagged(AsDtype('>i4'))
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.idProbabilities_[8]                                                                    | float[][8]               | AsJagged(AsDtype("('>f4', (...
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.tracksters_                                                                            | std::vector<edm::Ptr<... | AsObjects(AsArray(True, Fal...
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.trackPtr_.core_                                                                        | edm::RefCore[]           | AsJagged(AsStridedObjects(M...
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.trackPtr_.key_                                                                         | uint64_t[]               | AsJagged(AsDtype('>u8'))
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.time_                                                                                  | float[]                  | AsJagged(AsDtype('>f4'))
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.timeError_                                                                             | float[]                  | AsJagged(AsDtype('>f4'))
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.obj/TICLCandidates_ticlCandidate__RECO.obj.rawEnergy_                                                                             | float[]                  | AsJagged(AsDtype('>f4'))
# TICLCandidates_ticlCandidate__RECO./TICLCandidates_ticlCandidate__RECO.present                                                                                                                           | bool                     | AsDtype('bool')
# TrackCandidates_electronCkfTrackCandidates__RECO.                                                                                                                                                        | edm::Wrapper<vector<T... | AsGroup(<TBranchElement 'Tr...
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj                                                                                                   | (group of TrackCandid... | AsGroup(<TBranchElement 'Tr...
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.rh_.data_                                    | std::vector<TrackingR... | AsObjects(AsArray(True, Fal...
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.seed_.hits_.data_                            | unknown                  | <UnknownInterpretation 'non...
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.seed_.tsos_.theLocalParameters.theQbp        | float[]                  | AsJagged(AsDtype('>f4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.seed_.tsos_.theLocalParameters.theDxdz       | float[]                  | AsJagged(AsDtype('>f4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.seed_.tsos_.theLocalParameters.theDydz       | float[]                  | AsJagged(AsDtype('>f4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.seed_.tsos_.theLocalParameters.theX          | float[]                  | AsJagged(AsDtype('>f4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.seed_.tsos_.theLocalParameters.theY          | float[]                  | AsJagged(AsDtype('>f4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.seed_.tsos_.theLocalParameters.thePzSign     | int16_t[]                | AsJagged(AsDtype('>i2'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.seed_.tsos_.theLocalParameters.theCharge     | int16_t[]                | AsJagged(AsDtype('>i2'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.seed_.tsos_.theLocalErrors[15]               | float[][15]              | AsJagged(AsDtype("('>f4', (...
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.seed_.tsos_.thePt                            | float[]                  | AsJagged(AsDtype('>f4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.seed_.tsos_.thePack                          | uint32_t[]               | AsJagged(AsDtype('>u4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.seed_.dir_                                   | int32_t[]                | AsJagged(AsDtype('>i4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.state_.theLocalParameters.theQbp             | float[]                  | AsJagged(AsDtype('>f4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.state_.theLocalParameters.theDxdz            | float[]                  | AsJagged(AsDtype('>f4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.state_.theLocalParameters.theDydz            | float[]                  | AsJagged(AsDtype('>f4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.state_.theLocalParameters.theX               | float[]                  | AsJagged(AsDtype('>f4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.state_.theLocalParameters.theY               | float[]                  | AsJagged(AsDtype('>f4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.state_.theLocalParameters.thePzSign          | int16_t[]                | AsJagged(AsDtype('>i2'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.state_.theLocalParameters.theCharge          | int16_t[]                | AsJagged(AsDtype('>i2'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.state_.theLocalErrors[15]                    | float[][15]              | AsJagged(AsDtype("('>f4', (...
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.state_.thePt                                 | float[]                  | AsJagged(AsDtype('>f4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.state_.thePack                               | uint32_t[]               | AsJagged(AsDtype('>u4'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.seedRef_.holder_                             | edm::reftobase::BaseH... | AsJagged(AsStridedObjects(M...
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.nLoops_                                      | int8_t[]                 | AsJagged(AsDtype('int8'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.obj/TrackCandidates_electronCkfTrackCandidates__RECO.obj.stopReason_                                  | uint8_t[]                | AsJagged(AsDtype('uint8'))
# TrackCandidates_electronCkfTrackCandidates__RECO./TrackCandidates_electronCkfTrackCandidates__RECO.present                                                                                               | bool                     | AsDtype('bool')
# floats_ticlTracksterLinksSuperclustering__RECO.                                                                                                                                                          | edm::Wrapper<vector<f... | AsGroup(<TBranchElement 'fl...
# floats_ticlTracksterLinksSuperclustering__RECO./floats_ticlTracksterLinksSuperclustering__RECO.obj                                                                                                       | unknown                  | <UnknownInterpretation 'non...
# floats_ticlTracksterLinksSuperclustering__RECO./floats_ticlTracksterLinksSuperclustering__RECO.present                                                                                                   | bool                     | AsDtype('bool')
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.                                                                                                                                                   | edm::Wrapper<vector<r... | AsGroup(<TBranchElement 're...
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO./recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj                                                                                         | (group of recoCaloClu... | AsGroup(<TBranchElement 're...
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO./recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj/recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj.energy_                       | double[]                 | AsJagged(AsDtype('>f8'))
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO./recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj/recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj.correctedEnergy_              | double[]                 | AsJagged(AsDtype('>f8'))
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO./recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj/recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj.correctedEnergyUncertainty_   | float[]                  | AsJagged(AsDtype('>f4'))
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO./recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj/recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj.position_.fCoordinates.fX     | double[]                 | AsJagged(AsDtype('>f8'))
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO./recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj/recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj.position_.fCoordinates.fY     | double[]                 | AsJagged(AsDtype('>f8'))
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO./recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj/recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj.position_.fCoordinates.fZ     | double[]                 | AsJagged(AsDtype('>f8'))
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO./recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj/recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj.caloID_.detectors_            | uint32_t[]               | AsJagged(AsDtype('>u4'))
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO./recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj/recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj.hitsAndFractions_             | std::vector<pair<DetI... | AsObjects(AsArray(True, Fal...
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO./recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj/recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj.algoID_                       | int32_t[]                | AsJagged(AsDtype('>i4'))
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO./recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj/recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj.seedId_.id_                   | uint32_t[]               | AsJagged(AsDtype('>u4'))
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO./recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj/recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.obj.flags_                        | uint32_t[]               | AsJagged(AsDtype('>u4'))
# recoCaloClusters_ticlEGammaSuperClusterProducer__RECO./recoCaloClusters_ticlEGammaSuperClusterProducer__RECO.present                                                                                     | bool                     | AsDtype('bool')
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO.                                                                                                                                                         | edm::Wrapper<vector<r... | AsGroup(<TBranchElement 're...
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj                                                                                                     | (group of recoElectro... | AsGroup(<TBranchElement 're...
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.hits_.data_                                     | std::vector<TrackingR... | AsObjects(AsArray(True, Fal...
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.tsos_.theLocalParameters.theQbp                 | float[]                  | AsJagged(AsDtype('>f4'))
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.tsos_.theLocalParameters.theDxdz                | float[]                  | AsJagged(AsDtype('>f4'))
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.tsos_.theLocalParameters.theDydz                | float[]                  | AsJagged(AsDtype('>f4'))
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.tsos_.theLocalParameters.theX                   | float[]                  | AsJagged(AsDtype('>f4'))
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.tsos_.theLocalParameters.theY                   | float[]                  | AsJagged(AsDtype('>f4'))
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.tsos_.theLocalParameters.thePzSign              | int16_t[]                | AsJagged(AsDtype('>i2'))
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.tsos_.theLocalParameters.theCharge              | int16_t[]                | AsJagged(AsDtype('>i2'))
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.tsos_.theLocalErrors[15]                        | float[][15]              | AsJagged(AsDtype("('>f4', (...
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.tsos_.thePt                                     | float[]                  | AsJagged(AsDtype('>f4'))
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.tsos_.thePack                                   | uint32_t[]               | AsJagged(AsDtype('>u4'))
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.dir_                                            | int32_t[]                | AsJagged(AsDtype('>i4'))
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.ctfTrack_.product_                              | edm::RefCoreWithIndex[]  | AsJagged(AsStridedObjects(M...
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.caloCluster_.holder_                            | edm::reftobase::BaseH... | AsJagged(AsStridedObjects(M...
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.hitInfo_                                        | std::vector<reco::Ele... | AsObjects(AsArray(True, Fal...
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.nrLayersAlongTraj_                              | int32_t[]                | AsJagged(AsDtype('>i4'))
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.isEcalDriven_                                   | bool[]                   | AsJagged(AsDtype('bool'))
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj/recoElectronSeeds_ecalDrivenElectronSeeds__RECO.obj.isTrackerDriven_                                | bool[]                   | AsJagged(AsDtype('bool'))
# recoElectronSeeds_ecalDrivenElectronSeeds__RECO./recoElectronSeeds_ecalDrivenElectronSeeds__RECO.present                                                                                                 | bool                     | AsDtype('bool')
# recoElectronSeeds_electronMergedSeeds__RECO.                                                                                                                                                             | edm::Wrapper<vector<r... | AsGroup(<TBranchElement 're...
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj                                                                                                             | (group of recoElectro... | AsGroup(<TBranchElement 're...
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.hits_.data_                                                 | std::vector<TrackingR... | AsObjects(AsArray(True, Fal...
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.tsos_.theLocalParameters.theQbp                             | float[]                  | AsJagged(AsDtype('>f4'))
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.tsos_.theLocalParameters.theDxdz                            | float[]                  | AsJagged(AsDtype('>f4'))
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.tsos_.theLocalParameters.theDydz                            | float[]                  | AsJagged(AsDtype('>f4'))
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.tsos_.theLocalParameters.theX                               | float[]                  | AsJagged(AsDtype('>f4'))
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.tsos_.theLocalParameters.theY                               | float[]                  | AsJagged(AsDtype('>f4'))
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.tsos_.theLocalParameters.thePzSign                          | int16_t[]                | AsJagged(AsDtype('>i2'))
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.tsos_.theLocalParameters.theCharge                          | int16_t[]                | AsJagged(AsDtype('>i2'))
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.tsos_.theLocalErrors[15]                                    | float[][15]              | AsJagged(AsDtype("('>f4', (...
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.tsos_.thePt                                                 | float[]                  | AsJagged(AsDtype('>f4'))
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.tsos_.thePack                                               | uint32_t[]               | AsJagged(AsDtype('>u4'))
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.dir_                                                        | int32_t[]                | AsJagged(AsDtype('>i4'))
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.ctfTrack_.product_                                          | edm::RefCoreWithIndex[]  | AsJagged(AsStridedObjects(M...
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.caloCluster_.holder_                                        | edm::reftobase::BaseH... | AsJagged(AsStridedObjects(M...
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.hitInfo_                                                    | std::vector<reco::Ele... | AsObjects(AsArray(True, Fal...
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.nrLayersAlongTraj_                                          | int32_t[]                | AsJagged(AsDtype('>i4'))
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.isEcalDriven_                                               | bool[]                   | AsJagged(AsDtype('bool'))
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.obj/recoElectronSeeds_electronMergedSeeds__RECO.obj.isTrackerDriven_                                            | bool[]                   | AsJagged(AsDtype('bool'))
# recoElectronSeeds_electronMergedSeeds__RECO./recoElectronSeeds_electronMergedSeeds__RECO.present                                                                                                         | bool                     | AsDtype('bool')
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.                                                                                                                                                        | edm::Wrapper<vector<r... | AsGroup(<TBranchElement 're...
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj                                                                                                   | (group of recoGsfElec... | AsGroup(<TBranchElement 're...
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.m_state.vertex_.fCoordinates.fX              | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.m_state.vertex_.fCoordinates.fY              | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.m_state.vertex_.fCoordinates.fZ              | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.m_state.p4Polar_.fCoordinates.fPt            | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.m_state.p4Polar_.fCoordinates.fEta           | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.m_state.p4Polar_.fCoordinates.fPhi           | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.m_state.p4Polar_.fCoordinates.fM             | float[]                  | AsJagged(AsDtype('>f4', 'fl...
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.m_state.qx3_                                 | int32_t[]                | AsJagged(AsDtype('>i4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.m_state.pdgId_                               | int32_t[]                | AsJagged(AsDtype('>i4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.m_state.status_                              | int32_t[]                | AsJagged(AsDtype('>i4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.chargeInfo_.scPixCharge                      | int32_t[]                | AsJagged(AsDtype('>i4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.chargeInfo_.isGsfCtfScPixConsistent          | bool[]                   | AsJagged(AsDtype('bool'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.chargeInfo_.isGsfScPixConsistent             | bool[]                   | AsJagged(AsDtype('bool'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.chargeInfo_.isGsfCtfConsistent               | bool[]                   | AsJagged(AsDtype('bool'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.core_.product_                               | edm::RefCoreWithIndex[]  | AsJagged(AsStridedObjects(M...
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackClusterMatching_.electronCluster.core_  | unknown                  | <UnknownInterpretation 'non...
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackClusterMatching_.electronCluster.key_   | uint64_t[]               | AsJagged(AsDtype('>u8'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackClusterMatching_.eSuperClusterOverP     | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackClusterMatching_.eSeedClusterOverP      | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackClusterMatching_.eSeedClusterOverPout   | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackClusterMatching_.eEleClusterOverPout    | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackClusterMatching_.deltaEtaSuperCluste... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackClusterMatching_.deltaEtaSeedCluster... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackClusterMatching_.deltaEtaEleClusterA... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackClusterMatching_.deltaPhiEleClusterA... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackClusterMatching_.deltaPhiSuperCluste... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackClusterMatching_.deltaPhiSeedCluster... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.positionAtVtx.fCoord... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.positionAtVtx.fCoord... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.positionAtVtx.fCoord... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.positionAtCalo.fCoor... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.positionAtCalo.fCoor... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.positionAtCalo.fCoor... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumAtVtx.fCoord... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumAtVtx.fCoord... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumAtVtx.fCoord... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumAtCalo.fCoor... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumAtCalo.fCoor... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumAtCalo.fCoor... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumOut.fCoordin... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumOut.fCoordin... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumOut.fCoordin... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumAtEleClus.fC... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumAtEleClus.fC... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumAtEleClus.fC... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumAtVtxWithCon... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumAtVtxWithCon... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.trackExtrapolations_.momentumAtVtxWithCon... | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.fiducialFlags_.isEB                          | bool[]                   | AsJagged(AsDtype('bool'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.fiducialFlags_.isEE                          | bool[]                   | AsJagged(AsDtype('bool'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.fiducialFlags_.isEBEEGap                     | bool[]                   | AsJagged(AsDtype('bool'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.fiducialFlags_.isEBEtaGap                    | bool[]                   | AsJagged(AsDtype('bool'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.fiducialFlags_.isEBPhiGap                    | bool[]                   | AsJagged(AsDtype('bool'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.fiducialFlags_.isEEDeeGap                    | bool[]                   | AsJagged(AsDtype('bool'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.fiducialFlags_.isEERingGap                   | bool[]                   | AsJagged(AsDtype('bool'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.showerShape_.sigmaEtaEta                     | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.showerShape_.sigmaIetaIeta                   | float[]                  | AsJagged(AsDtype('>f4'))
# recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO./recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj/recoGsfElectrons_ecalDrivenGsfElectronsHGC__RECO.obj.showerShape_.sigmaIphiIphi                   | float[]                  | AsJagged(AsDtype('>f4'))
# ...
# ticlTracksters_ticlCandidate__RECO./ticlTracksters_ticlCandidate__RECO.obj/ticlTracksters_ticlCandidate__RECO.obj.track_idx_                                                                             | int32_t[]                | AsJagged(AsDtype('>i4'))
# ticlTracksters_ticlCandidate__RECO./ticlTracksters_ticlCandidate__RECO.obj/ticlTracksters_ticlCandidate__RECO.obj.eigenvectors_[3]                                                                       | ROOT::Math::Displacem... | AsJagged(AsStridedObjects(M...
# ticlTracksters_ticlCandidate__RECO./ticlTracksters_ticlCandidate__RECO.obj/ticlTracksters_ticlCandidate__RECO.obj.eigenvalues_[3]                                                                        | float[][3]               | AsJagged(AsDtype("('>f4', (...
# ticlTracksters_ticlCandidate__RECO./ticlTracksters_ticlCandidate__RECO.obj/ticlTracksters_ticlCandidate__RECO.obj.sigmas_[3]                                                                             | float[][3]               | AsJagged(AsDtype("('>f4', (...
# ticlTracksters_ticlCandidate__RECO./ticlTracksters_ticlCandidate__RECO.obj/ticlTracksters_ticlCandidate__RECO.obj.sigmasPCA_[3]                                                                          | float[][3]               | AsJagged(AsDtype("('>f4', (...
# ticlTracksters_ticlCandidate__RECO./ticlTracksters_ticlCandidate__RECO.obj/ticlTracksters_ticlCandidate__RECO.obj.edges_                                                                                 | std::vector<array<uns... | AsObjects(AsArray(True, Fal...
# ticlTracksters_ticlCandidate__RECO./ticlTracksters_ticlCandidate__RECO.obj/ticlTracksters_ticlCandidate__RECO.obj.iterationIndex_                                                                        | uint8_t[]                | AsJagged(AsDtype('uint8'))
# ticlTracksters_ticlCandidate__RECO./ticlTracksters_ticlCandidate__RECO.present                                                                                                                           | bool                     | AsDtype('bool')
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO.                                                                                                                                                  | edm::Wrapper<vector<t... | AsGroup(<TBranchElement 'ti...
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj                                                                                       | (group of ticlTrackst... | AsGroup(<TBranchElement 'ti...
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.barycenter_.fCoordinate... | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.barycenter_.fCoordinate... | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.barycenter_.fCoordinate... | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.regressed_energy_          | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.raw_energy_                | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.time_                      | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.boundTime_                 | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.timeError_                 | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.id_probabilities_[8]       | float[][8]               | AsJagged(AsDtype("('>f4', (...
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.vertices_                  | std::vector<uint32_t>[]  | AsObjects(AsArray(True, Fal...
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.vertex_multiplicity_       | std::vector<float>[]     | AsObjects(AsArray(True, Fal...
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.raw_pt_                    | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.raw_em_pt_                 | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.raw_em_energy_             | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.seedID_.processIndex_      | uint16_t[]               | AsJagged(AsDtype('>u2'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.seedID_.productIndex_      | uint16_t[]               | AsJagged(AsDtype('>u2'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.seedIndex_                 | int32_t[]                | AsJagged(AsDtype('>i4'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.track_idx_                 | int32_t[]                | AsJagged(AsDtype('>i4'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.eigenvectors_[3]           | ROOT::Math::Displacem... | AsJagged(AsStridedObjects(M...
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.eigenvalues_[3]            | float[][3]               | AsJagged(AsDtype("('>f4', (...
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.sigmas_[3]                 | float[][3]               | AsJagged(AsDtype("('>f4', (...
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.sigmasPCA_[3]              | float[][3]               | AsJagged(AsDtype("('>f4', (...
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.edges_                     | std::vector<array<uns... | AsObjects(AsArray(True, Fal...
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering__RECO.obj.iterationIndex_            | uint8_t[]                | AsJagged(AsDtype('uint8'))
# ticlTracksters_ticlTracksterLinksSuperclustering__RECO./ticlTracksters_ticlTracksterLinksSuperclustering__RECO.present                                                                                   | bool                     | AsDtype('bool')
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.                                                                                                                                            | edm::Wrapper<vector<t... | AsGroup(<TBranchElement 'ti...
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj                                                                           | (group of ticlTrackst... | AsGroup(<TBranchElement 'ti...
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.baryc... | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.baryc... | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.baryc... | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.regre... | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.raw_e... | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.time_    | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.bound... | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.timeE... | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.id_pr... | float[][8]               | AsJagged(AsDtype("('>f4', (...
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.verti... | std::vector<uint32_t>[]  | AsObjects(AsArray(True, Fal...
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.verte... | std::vector<float>[]     | AsObjects(AsArray(True, Fal...
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.raw_pt_  | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.raw_e... | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.raw_e... | float[]                  | AsJagged(AsDtype('>f4'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.seedI... | uint16_t[]               | AsJagged(AsDtype('>u2'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.seedI... | uint16_t[]               | AsJagged(AsDtype('>u2'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.seedI... | int32_t[]                | AsJagged(AsDtype('>i4'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.track... | int32_t[]                | AsJagged(AsDtype('>i4'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.eigen... | ROOT::Math::Displacem... | AsJagged(AsStridedObjects(M...
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.eigen... | float[][3]               | AsJagged(AsDtype("('>f4', (...
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.sigma... | float[][3]               | AsJagged(AsDtype("('>f4', (...
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.sigma... | float[][3]               | AsJagged(AsDtype("('>f4', (...
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.edges_   | std::vector<array<uns... | AsObjects(AsArray(True, Fal...
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj/ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.obj.itera... | uint8_t[]                | AsJagged(AsDtype('uint8'))
# ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO./ticlTracksters_ticlTracksterLinksSuperclustering_CLUE3D_RECO.present                                                                       | bool                     | AsDtype('bool')

# %%
t["floats_ticlTracksterLinksSuperclustering__RECO./floats_ticlTracksterLinksSuperclustering__RECO.obj"].debug_array(0)
# Out:
# array([ 64,   7,   1, ..., 128,   0,   0], dtype=uint8)
