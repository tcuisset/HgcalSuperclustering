# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("../..")
import glob
from pathlib import Path
import htcondor

# %%
from jobTools import *

# %%
sched = htcondor.Schedd()

# %%
pathToConfig = Path("../../../runs/AlessandroElectronConfigs/step3_ticlDumper_hgcalEvtDump.py")
pathToOutput = Path("/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1")

# %%
inputFiles
# Out:
# [InputFile(path=PosixPath('/data_cms_upgrade/cuisset/supercls/alessandro_electrons/input-oppositeSign/step2_205.root'), ntupleId='205', sameSign=False),
#  InputFile(path=PosixPath('/data_cms_upgrade/cuisset/supercls/alessandro_electrons/input-oppositeSign/step2_204.root'), ntupleId='204', sameSign=False),
#  InputFile(path=PosixPath('/data_cms_upgrade/cuisset/supercls/alessandro_electrons/input-oppositeSign/step2_215.root'), ntupleId='215', sameSign=False),
#  InputFile(path=PosixPath('/data_cms_upgrade/cuisset/supercls/alessandro_electrons/input-oppositeSign/step2_211.root'), ntupleId='211', sameSign=False),
#  InputFile(path=PosixPath('/data_cms_upgrade/cuisset/supercls/alessandro_electrons/input-oppositeSign/step2_232.root'), ntupleId='232', sameSign=False),
#  InputFile(path=PosixPath('/data_cms_upgrade/cuisset/supercls/alessandro_electrons/input-oppositeSign/step2_257.root'), ntupleId='257', sameSign=False),
# ...

# %%
arguments = makeArgumentsForCmsRunConfigStarter(pathToConfig, inputFiles[0].path, outputDir=pathToOutput,  maxEvents=1)
arguments
# Out:
# "'/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/cmssw_jobs/cmsRunConfigStarter.py' -- -s /grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/runs/AlessandroElectronConfigs/step3_ticlDumper_hgcalEvtDump.py -i /grid_mnt/data_cms_upgrade/tarabini/electrons_pre4_PU_oppositeSign_new/step2/step2_205.root '--output-fevt=/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1/step3_$(SampleId).root' '--output-dqm=/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1/step3_inDQM_$(SampleId).root' '--output-fileService=/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1/dumper_$(SampleId).root' 'process.maxEvents.input=cms.untracked.int32(1)'"

# %%
print(makeSubmitStringTemplate(arguments, "logs", pathToCmssw, t3queue="short"))
# Out:
# executable = /grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/cmssw_jobs/cmsenvStarter.sh
# arguments = "cmsRun '/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/cmssw_jobs/cmsRunConfigStarter.py' -- -s /grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/runs/AlessandroElectronConfigs/step3_ticlDumper_hgcalEvtDump.py -i /grid_mnt/data_cms_upgrade/tarabini/electrons_pre4_PU_oppositeSign_new/step2/step2_205.root '--output-fevt=/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1/step3_$(SampleId).root' '--output-dqm=/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1/step3_inDQM_$(SampleId).root' '--output-fileService=/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1/dumper_$(SampleId).root' 'process.maxEvents.input=cms.untracked.int32(1)'"
# environment = "CMSSW_BASE='/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/CMSSW_13_2_5_patch2'"
# universe = vanilla
# ...

# %%
sub = makeSubmitObject(arguments, "logs", pathToCmssw, t3queue="short")
print(sub)
# Out:
# executable = /grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/cmssw_jobs/cmsenvStarter.sh
# arguments = cmsRun '/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/cmssw_jobs/cmsRunConfigStarter.py' -- -s /grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/runs/AlessandroElectronConfigs/step3_ticlDumper_hgcalEvtDump.py -i /grid_mnt/data_cms_upgrade/tarabini/electrons_pre4_PU_oppositeSign_new/step2/step2_205.root '--output-fevt=/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1/step3_$(SampleId).root' '--output-dqm=/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1/step3_inDQM_$(SampleId).root' '--output-fileService=/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1/dumper_$(SampleId).root' 'process.maxEvents.input=cms.untracked.int32(1)'
# environment = "CMSSW_BASE='/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/CMSSW_13_2_5_patch2'"
# universe = vanilla
# ...

# %%
sub_res = sched.submit(sub, itemdata=iter([{"SampleId" : "14test"}]))
sub_res
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
sub_res.cluster()
# Out:
# 2265976

# %%
list(sub.jobs(itemdata=iter([{"SampleId" : "5"}])))[0]["Args"]
# Out:
# "cmsRun '/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/cmssw_jobs/cmsRunConfigStarter.py' -- -s /grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/runs/AlessandroElectronConfigs/step3_ticlDumper_hgcalEvtDump.py -i /grid_mnt/data_cms_upgrade/tarabini/electrons_pre4_PU_oppositeSign_new/step2/step2_205.root '--output-fevt=/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1/step3_5.root' '--output-dqm=/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1/step3_inDQM_5.root' '--output-fileService=/grid_mnt/data_cms_upgrade/cuisset/supercls/alessandro_electrons/supercls-v1/dumper_5.root' 'process.maxEvents.input=cms.untracked.int32(1)'"
