# %%
import onnx

# %%
with open("/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/CMSSW_14_0_0_pre0/external/slc7_amd64_gcc12/data/RecoHGCal/TICL/data/tf_models/supercls_v2_Mar24_20-35.onnx", "rb") as f:
    model = onnx.load(f)

# %%
model
# Out:
# ir_version: 5
# producer_name: "pytorch"
# producer_version: "2.2.1"
# graph {
#   node {
#     input: "input"
#     input: "0.scaler_scale"
#     output: "/0/Mul_output_0"
#     name: "/0/Mul"
#     op_type: "Mul"
# ...
