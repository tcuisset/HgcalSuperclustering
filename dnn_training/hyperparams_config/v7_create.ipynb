# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs")
import optuna
from dnn_training.hyperparams_config.v7 import *
from dnn_training.hyperparameter_scan import *
# Out:
# /grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/dnn_training/hyperparams_config/v7.py:46: ExperimentalWarning: JournalStorage is experimental (supported from v3.1.0). The interface can change in the future.
#   storage=optuna.storages.JournalStorage(optuna.storages.JournalFileStorage(args.output + f"/journal_optuna_{args.studyName}.log"),)

# %%
study = optuna.create_study(**study_kwargs, load_if_exists=True)
# Out:
# [I 2024-05-16 22:17:54,762] A new study created in Journal with name: hp-v7-cmssw

# %%
v6 = optuna.load_study(study_name="hp-v6-cmssw",
        storage=optuna.storages.JournalStorage(optuna.storages.JournalFileStorage("/grid_mnt/data_cms_upgrade/cuisset/supercls/dnn_training/hyperparams-v6/cmssw/journal_optuna_hp-v6-cmssw.log"),))
# Out:
# /tmp/ipykernel_145009/2765786345.py:2: ExperimentalWarning: JournalStorage is experimental (supported from v3.1.0). The interface can change in the future.
#   storage=optuna.storages.JournalStorage(optuna.storages.JournalFileStorage("/grid_mnt/data_cms_upgrade/cuisset/supercls/dnn_training/hyperparams-v6/cmssw/journal_optuna_hp-v6-cmssw.log"),))

# %%
df = v6.trials_dataframe().sort_values("value", ascending=False)
df
# Out:
#     number     value             datetime_start          datetime_complete  \
# 43      43  0.692368 2024-05-10 20:23:39.440896 2024-05-11 11:23:30.289013
# 27      27  0.692105 2024-05-09 15:37:39.246683 2024-05-10 21:59:35.072542
# 42      42  0.691579 2024-05-10 20:04:44.247506 2024-05-11 13:30:10.752604
# 19      19  0.691579 2024-05-09 08:00:39.306786 2024-05-09 22:01:14.786036
# 6        6  0.690526 2024-05-08 22:50:46.250241 2024-05-09 05:23:07.815515
# 28      28  0.690000 2024-05-09 16:32:36.265055 2024-05-10 13:16:47.901652
# 36      36  0.689737 2024-05-10 07:05:23.311824 2024-05-10 14:55:16.010012
# 4        4  0.689474 2024-05-08 22:50:42.310300 2024-05-09 06:37:32.142154
# 25      25  0.688947 2024-05-09 14:46:57.782867 2024-05-10 21:45:53.423284
# 5        5  0.688684 2024-05-08 22:50:44.249497 2024-05-09 05:51:05.113493
# 35      35  0.688158 2024-05-10 06:54:26.885870 2024-05-10 13:16:27.194640
# ...

# %%
df.columns
# Out:
# Index(['number', 'value', 'datetime_start', 'datetime_complete', 'duration',
#        'params_batchSize', 'params_dropout', 'params_lr',
#        'params_trainingLossType', 'params_weightSamples',
#        'user_attrs_all_metrics', 'user_attrs_best_val_metrics_epochs',
#        'user_attrs_best_val_metrics_values', 'user_attrs_log_output',
#        'user_attrs_nEpochs', 'user_attrs_run_name',
#        'user_attrs_saved_models_paths', 'system_attrs_fixed_params', 'state'],
#       dtype='object')

# %%
params_cols = [col for col in df.columns if col.startswith("params_")]
params_cols
# Out:
# ['params_batchSize',
#  'params_dropout',
#  'params_lr',
#  'params_trainingLossType',
#  'params_weightSamples']

# %%
for i, row in enumerate(df.itertuples()):
    params = {param[len("params_"):] : getattr(row, param) for param in params_cols}
    print(params)
    study.enqueue_trial(params)
    if i >= 15: break
# Out:
# {'batchSize': 130, 'dropout': 0.19151922930611515, 'lr': 0.0011383386080332156, 'trainingLossType': 'continuousAssociationScore', 'weightSamples': False}
# {'batchSize': 68, 'dropout': 0.21455166938806963, 'lr': 0.0006825884212945223, 'trainingLossType': 'continuousAssociationScore', 'weightSamples': False}
# {'batchSize': 114, 'dropout': 0.19082947654491073, 'lr': 0.00015011642913456496, 'trainingLossType': 'continuousAssociationScore', 'weightSamples': False}
# {'batchSize': 165, 'dropout': 0.00559474313953402, 'lr': 0.002860285043286187, 'trainingLossType': 'binary', 'weightSamples': True}
# {'batchSize': 445, 'dropout': 0.12292253178382637, 'lr': 0.0008113693944546176, 'trainingLossType': 'continuousAssociationScore', 'weightSamples': False}
# {'batchSize': 96, 'dropout': 0.20788598036817718, 'lr': 0.0006218534980535008, 'trainingLossType': 'continuousAssociationScore', 'weightSamples': False}
# ...
