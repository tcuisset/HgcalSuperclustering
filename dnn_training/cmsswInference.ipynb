# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
import torch
import optuna
from dnn_training.trainer import *
from dnn_training.hyperparameter_scan import *
from cmsswInference import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 import torch
#       6 import optuna
# ----> 7 from dnn_training.trainer import *
#       8 from dnn_training.hyperparameter_scan import *
#       9 from cmsswInference import *
#
# ModuleNotFoundError: No module named 'dnn_training'

# %%
runInferenceCMSSW_bound = functools.partial(runInferenceCMSSW,
        cmssw_release_path="/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/CMSSW_14_1_X_2024-04-29-1100",
        cmssw_py_config_path="/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/runs/NewElectronsD98/rereco.py",
        cmssw_py_config_path_harvesting="/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/runs/NewElectronsD98/step4.py",
        #output_path="/grid_mnt/data_cms_upgrade/cuisset/supercls/dnn_training/test/inference-tests/v1f",
        #model_path="/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/trained-dnn/current/supercls_v2_Apr05_14-48.onnx", dnn_wp=0.85,
        input_files=[f"/grid_mnt/data_cms_upgrade/cuisset/supercls/NewElectronsD98/v2-65772-mustache/step3_{i}.root" for i in range(1, 31)],
        input_wDQM_forComparison="/grid_mnt/data_cms_upgrade/cuisset/supercls/NewElectronsD98/v2-65772-mustache/DQM/DQM_V0001_R000000001__Global__CMSSW_X_Y_Z__RECO.root"
)

# %%
study = optuna.load_study(study_name="hp-v6-cmssw", storage=optuna.storages.JournalStorage(optuna.storages.JournalFileStorage("/grid_mnt/data_cms_upgrade/cuisset/supercls/dnn_training/hyperparams-v6/cmssw/journal_optuna_hp-v6-cmssw.log")))
study # =
# Out:
# /tmp/ipykernel_164079/3549495432.py:1: ExperimentalWarning: JournalStorage is experimental (supported from v3.1.0). The interface can change in the future.
#   study = optuna.load_study(study_name="hp-v6-cmssw", storage=optuna.storages.JournalStorage(optuna.storages.JournalFileStorage("/grid_mnt/data_cms_upgrade/cuisset/supercls/dnn_training/hyperparams-v6/cmssw/journal_optuna_hp-v6-cmssw.log")))

# %%
df = study.trials_dataframe().sort_values("value", ascending=False)
df
# Out:
#     number     value             datetime_start          datetime_complete  \
# 43      43  0.692368 2024-05-10 20:23:39.440896 2024-05-11 11:23:30.289013
# 27      27  0.692105 2024-05-09 15:37:39.246683 2024-05-10 21:59:35.072542
# 42      42  0.691579 2024-05-10 20:04:44.247506 2024-05-11 13:30:10.752604
# 19      19  0.691579 2024-05-09 08:00:39.306786 2024-05-09 22:01:14.786036
# 6        6  0.690526 2024-05-08 22:50:46.250241 2024-05-09 05:23:07.815515
# 28      28  0.690000 2024-05-09 16:32:36.265055 2024-05-10 13:16:47.901652
# 36      36  0.689737 2024-05-10 07:05:23.311824 2024-05-10 14:55:16.010012
# 4        4  0.689474 2024-05-08 22:50:42.310300 2024-05-09 06:37:32.142154
# 25      25  0.688947 2024-05-09 14:46:57.782867 2024-05-10 21:45:53.423284
# 5        5  0.688684 2024-05-08 22:50:44.249497 2024-05-09 05:51:05.113493
# 35      35  0.688158 2024-05-10 06:54:26.885870 2024-05-10 13:16:27.194640
# ...

# %%
df.iloc[0]
# Out:
# number                                                                               43
# value                                                                          0.692368
# datetime_start                                               2024-05-10 20:23:39.440896
# datetime_complete                                            2024-05-11 11:23:30.289013
# duration                                                         0 days 14:59:50.848117
# params_batchSize                                                                    130
# params_dropout                                                                 0.191519
# params_lr                                                                      0.001138
# params_trainingLossType                                      continuousAssociationScore
# params_weightSamples                                                              False
# user_attrs_all_metrics                {'Loss_val': {'1': 0.003623472061008215, '2': ...
# ...

# %%
python3 -m dnn_training.cmsswInference --cmssw "/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/CMSSW_14_1_X_2024-04-29-1100" \
        --cmsswConfig "/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/runs/NewElectronsD98/rereco_WPscan.py" --cmsswConfigHarvesting "/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/runs/NewElectronsD98/step4_WPscan.py" \
        --DQMForComparison "/grid_mnt/data_cms_upgrade/cuisset/supercls/NewElectronsD98/v2-65772-mustache/DQM/DQM_V0001_R000000001__Global__CMSSW_X_Y_Z__RECO.root" \
        --cmsswInputFiles $(for i in `seq 1 30`; do echo -n "/grid_mnt/data_cms_upgrade/cuisset/supercls/NewElectronsD98/v2-65772-mustache/step3_${i}.root "; done) \
        --output "/grid_mnt/data_cms_upgrade/cuisset/supercls/dnn_training/test/inference-tests/v1h" 
        --model "/grid_mnt/vol_home/llr/cms/cuisset/hgcal/supercls/repoForJobs/trained-dnn/current/supercls_v2_Apr05_14-48.onnx"

# %%
df[df.]

# %%
runInferenceCMSSW_bound(
    output_path="/grid_mnt/data_cms_upgrade/cuisset/supercls/dnn_training/hyperparams-v6/binary/41-May06_18-52-17/inference",
    model_path="/grid_mnt/data_cms_upgrade/cuisset/supercls/dnn_training/hyperparams-v6/binary/41-May06_18-52-17/model_lastEpoch_299.onnx",
    dnn_wp=0.3
)
# Out:
# 2024-05-07 16:09:18.142782: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 07-May-2024 16:09:20 CESTSuccessfully opened file file:step3_inDQM.root
# %MSG-e BtlSimHitsHarvester:   BtlSimHitsHarvester:btlSimHitsPostProcessor@endProcessBlock  07-May-2024 16:09:31 CEST post-events
# Monitoring histograms not found!
# %MSG
# %MSG-e BtlLocalRecoHarvester:   BtlLocalRecoHarvester:btlLocalRecoPostProcessor@endProcessBlock  07-May-2024 16:09:31 CEST post-events
# Monitoring histograms not found!
# %MSG
# %MSG-e MtdTracksHarvester:   MtdTracksHarvester:MtdTracksPostProcessor@endProcessBlock  07-May-2024 16:09:31 CEST post-events
# Monitoring histograms not found!
# %MSG
# ...
